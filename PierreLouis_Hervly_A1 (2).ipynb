# %% [markdown]
# Rename the notebook Lastname.Firstname-A1.ipynb
#
# 1. Download real estate listings for a town of your choice from redfin.com.
# 2. Load the data into a dataframe.
#
# 2 pts.

# %%
import pandas as pd
df = pd.read_csv('/content/redfin_2024-09-24-09-36-32.csv')

# %% [markdown]
# 3. Evaluate data types and null values among the data
#
# 2 pts.

# %%
df.head()
# Out:
#                                            SALE TYPE  SOLD DATE  \
# 0  In accordance with local MLS rules, some MLS l...        NaN
# 1                                        MLS Listing        NaN
# 2                                        MLS Listing        NaN
# 3                                        MLS Listing        NaN
# 4                                        MLS Listing        NaN
#
#                PROPERTY TYPE                  ADDRESS          CITY  \
# 0                        NaN                      NaN           NaN
# 1                Condo/Co-op    4528 Colbath Ave #103  Sherman Oaks
# 2  Single Family Residential  14560 Valley Vista Blvd  Sherman Oaks
# 3  Single Family Residential       5453 Hazeltine Ave  Sherman Oaks
# 4  Single Family Residential         4184 Knobhill Dr  Sherman Oaks
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  ...  STATUS  \
# 0               NaN                 NaN        NaN   NaN    NaN  ...     NaN
# 1                CA             91423.0   595000.0   1.0    1.0  ...  Active
# 2                CA             91403.0  2385000.0   4.0    4.0  ...  Active
# 3                CA             91401.0  2295000.0   5.0    4.0  ...  Active
# 4                CA             91403.0  1799000.0   3.0    3.0  ...  Active
#
#    NEXT OPEN HOUSE START TIME    NEXT OPEN HOUSE END TIME  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3  September-24-2024 11:00 AM  September-24-2024 02:00 PM
# 4                         NaN                         NaN
#
#    URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)  \
# 0                                                NaN
# 1  https://www.redfin.com/CA/Sherman-Oaks/4528-Co...
# 2  https://www.redfin.com/CA/Sherman-Oaks/14560-V...
# 3  https://www.redfin.com/CA/Sherman-Oaks/5453-Ha...
# 4  https://www.redfin.com/CA/Sherman-Oaks/4184-Kn...
#
#    SOURCE        MLS#  FAVORITE INTERESTED   LATITUDE   LONGITUDE
# 0     NaN         NaN       NaN        NaN        NaN         NaN
# 1   CRMLS  BB24167913         N          Y  34.153884 -118.436279
# 2   CRMLS  SR24158086         N          Y  34.147024 -118.451649
# 3  TheMLS   24-443047         N          Y  34.170170 -118.440322
# 4  TheMLS   24-443611         N          Y  34.145617 -118.448777
#
# [5 rows x 27 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 27 columns):
#  #   Column                                                                                       Non-Null Count  Dtype
# ---  ------                                                                                       --------------  -----
#  0   SALE TYPE                                                                                    267 non-null    object
#  1   SOLD DATE                                                                                    0 non-null      float64
#  2   PROPERTY TYPE                                                                                266 non-null    object
#  3   ADDRESS                                                                                      266 non-null    object
#  4   CITY                                                                                         266 non-null    object
#  5   STATE OR PROVINCE                                                                            266 non-null    object
#  6   ZIP OR POSTAL CODE                                                                           266 non-null    float64
#  7   PRICE                                                                                        266 non-null    float64
#  8   BEDS                                                                                         248 non-null    float64
#  9   BATHS                                                                                        247 non-null    float64
#  10  LOCATION                                                                                     265 non-null    object
#  11  SQUARE FEET                                                                                  245 non-null    float64
#  12  LOT SIZE                                                                                     263 non-null    float64
#  13  YEAR BUILT                                                                                   246 non-null    float64
#  14  DAYS ON MARKET                                                                               266 non-null    float64
#  15  $/SQUARE FEET                                                                                245 non-null    float64
#  16  HOA/MONTH                                                                                    70 non-null     float64
#  17  STATUS                                                                                       266 non-null    object
#  18  NEXT OPEN HOUSE START TIME                                                                   23 non-null     object
#  19  NEXT OPEN HOUSE END TIME                                                                     23 non-null     object
#  20  URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)  266 non-null    object
#  21  SOURCE                                                                                       266 non-null    object
#  22  MLS#                                                                                         266 non-null    object
#  23  FAVORITE                                                                                     266 non-null    object
#  24  INTERESTED                                                                                   266 non-null    object
#  25  LATITUDE                                                                                     266 non-null    float64
#  26  LONGITUDE                                                                                    266 non-null    float64
# dtypes: float64(13), object(14)
# memory usage: 56.4+ KB

# %% [markdown]
# 4. Assess the range of values (min, max, quartiles) in each numeric field.
#
# 2 pts.

# %%
df.describe().transpose()
# Out:
#                     count          mean           std            min  \
# SOLD DATE             0.0           NaN           NaN            NaN
# ZIP OR POSTAL CODE  266.0  9.134575e+04  3.007896e+02   90049.000000
# PRICE               266.0  2.613361e+06  3.701926e+06  130000.000000
# BEDS                248.0  4.669355e+00  5.169549e+00       0.000000
# BATHS               247.0  4.696356e+00  5.769180e+00       1.000000
# SQUARE FEET         245.0  3.567992e+03  3.979560e+03     536.000000
# LOT SIZE            263.0  1.992655e+04  3.234812e+04    1676.000000
# YEAR BUILT          246.0  1.973268e+03  2.695244e+01    1926.000000
# DAYS ON MARKET      266.0  6.269173e+01  7.693130e+01       1.000000
# $/SQUARE FEET       245.0  7.742612e+02  3.059133e+02     279.000000
# HOA/MONTH            70.0  5.785571e+02  2.337065e+02      67.000000
# LATITUDE            266.0  3.415311e+01  1.253108e-02      34.127576
# LONGITUDE           266.0 -1.184463e+02  1.755241e-02    -118.486901
#
#                               25%           50%           75%           max
# SOLD DATE                     NaN           NaN           NaN           NaN
# ZIP OR POSTAL CODE   91403.000000  9.140300e+04  9.142300e+04  9.160700e+04
# PRICE               805500.000000  1.927500e+06  3.195000e+06  4.800000e+07
# BEDS                     3.000000  4.000000e+00  5.000000e+00  5.600000e+01
# BATHS                    2.000000  3.500000e+00  5.000000e+00  5.800000e+01
# SQUARE FEET           1541.000000  2.548000e+03  3.874000e+03  3.919800e+04
# LOT SIZE              6909.000000  1.016300e+04  2.031800e+04  3.864720e+05
# YEAR BUILT            1950.000000  1.966000e+03  1.989000e+03  2.025000e+03
# DAYS ON MARKET          18.000000  4.000000e+01  8.100000e+01  6.630000e+02
# $/SQUARE FEET          571.000000  7.470000e+02  9.210000e+02  3.191000e+03
# HOA/MONTH              470.250000  5.340000e+02  6.580000e+02  1.800000e+03
# LATITUDE                34.144289  3.415267e+01  3.416313e+01  3.417878e+01
# LONGITUDE             -118.457919 -1.184480e+02 -1.184323e+02 -1.184127e+02

# %% [markdown]
# 5. Assess the intercorrelations among the numeric features in the dataset using a heatmap.
#
# 2 pts.

# %%
df.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME',
#        'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)',
#        'SOURCE', 'MLS#', 'FAVORITE', 'INTERESTED', 'LATITUDE', 'LONGITUDE'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns


sns.pairplot(df[['PRICE', 'BEDS', 'BATHS', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET', '$/SQUARE FEET']])
plt.show()

# %%
numeric_df = df.select_dtypes(include=[np.number])
corr = numeric_df.corr()
mask = np.triu(np.ones_like(corr, dtype=bool))
plt.figure(figsize=(10, 8))
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0, annot=True,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

plt.show()

# %% [markdown]
# 6. Assess intercorrelations among bedrooms and bathrooms using a jointplot.
#
# 2 pts.

# %%
sns.jointplot(x="BEDS", y="BATHS", data=df);

# %% [markdown]
# Based on the results above answer the following questions using a separate text cell.
#
# 1. What is the target variable in this dataset? (2 pts.)
# 2. Which fields have missing values and what is the proportion of missing values for each field (2 pts.)
# 3. Are there categorical features that are represented by numbers? (2 pts.)
# 4. Which (multinomial) fields would need to be dummy coded for modeling? (2 pts.)
# 5. Is there evidence of multicollinearity (correlation among features)? (2 pts.)

# %% [markdown]
# 1. According to the results above the target variable in this dataset would be price. As the price is correlated with the amount of bedrooms and bathrooms, the square feet, and the zipcode.

# %% [markdown]
# 2. SOLD DATE: 100% missing
# PROPERTY TYPE: ~0.37% missing
# ADDRESS: ~0.37% missing
# CITY: ~0.37% missing
# STATE OR PROVINCE: ~0.37% missing
# ZIP OR POSTAL CODE: ~0.37% missing
# BEDS: ~7.11% missing
# BATHS: ~7.49% missing
# SQUARE FEET: ~8.24% missing
# LOT SIZE: ~1.5% missing
# YEAR BUILT: ~7.87% missing
# $/SQUARE FEET: ~8.24% missing
# HOA/MONTH: ~73.77% missing
# NEXT OPEN HOUSE START TIME: ~91.39% missing
# NEXT OPEN HOUSE END TIME: ~91.39% missing

# %% [markdown]
#  3. Zipcode is a categorical variable that is represented by numbers.

# %% [markdown]
# 4. The fields that will have to dummy coded are Sale Type, State, Zipcode, City, Property Type, and Status.

# %% [markdown]
# 5. The correlation amongst features are bed/baths and price/square feet.
